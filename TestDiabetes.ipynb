# %% [markdown]
# <a href="https://colab.research.google.com/github/shahriariit/DiabetesAnalysis/blob/master/TestDiabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
x1 = pd.read_excel("data.xlsx", sheet_name='accuracy2', index_col=0)
x2 = pd.read_excel("data.xlsx", sheet_name='kappa2'   , index_col=0)
x3 = pd.read_excel("data.xlsx", sheet_name='auroc2'   , index_col=0)
x4 = pd.read_excel("data.xlsx", sheet_name='sensitivity2'   , index_col=0)
x5 = pd.read_excel("data.xlsx", sheet_name='specificity2'   , index_col=0)
x6 = pd.read_excel("data.xlsx", sheet_name='logloss2' , index_col=0)
xall= pd.read_excel("data.xlsx", sheet_name='overall' , index_col=0)
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-2-9f2415f354b2> in <module>()
# ----> 1 x1 = pd.read_excel("https://github.com/shahriariit/opendataset/blob/master/data.xlsx", sheet_name='accuracy2', index_col=0)
#       2 x2 = pd.read_excel("https://github.com/shahriariit/opendataset/blob/master/data.xlsx", sheet_name='kappa2'   , index_col=0)
#       3 x3 = pd.read_excel("https://github.com/shahriariit/opendataset/blob/master/data.xlsx", sheet_name='auroc2'   , index_col=0)
#       4 x4 = pd.read_excel("https://github.com/shahriariit/opendataset/blob/master/data.xlsx", sheet_name='sensitivity2'   , index_col=0)
#       5 x5 = pd.read_excel("https://github.com/shahriariit/opendataset/blob/master/data.xlsx", sheet_name='specificity2'   , index_col=0)
#
# /usr/local/lib/python3.6/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
SMALL_SIZE = 22
MEDIUM_SIZE = 20
BIGGER_SIZE = 22

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
x1
# Out:
#          Min.    Median      Mean      Max.
# S/N
# C1   69.73684  77.92208  77.73411  89.61039
# C2   68.42105  77.92208  77.54956  88.31169
# C3   67.10526  77.92208  77.44498  88.31169
# C4   68.42105  77.92208  77.49692  88.31169
# C5   67.10526  77.92208  77.57485  88.31169
# C6   67.10526  77.92208  77.44498  88.31169
# C7   67.10526  77.92208  77.44532  88.31169
# C8   67.10526  77.92208  77.31613  88.31169
# C9   69.73684  77.92208  77.29187  88.31169
# C10  69.73684  77.92208  77.16234  85.71429
# C11  67.10526  77.92208  77.44771  88.31169
# C12  68.83117  77.77683  77.47300  90.90909
# C13  67.10526  77.77683  76.95489  88.31169
# C14  69.73684  77.92208  77.31750  88.31169
# C15  71.05263  77.92208  77.62884  88.31169
# C16  68.83117  76.62338  77.44361  87.01299

# %%
x1_1 = x1.iloc[0:16, 0]
x1_2 = x1.iloc[0:16, 1]
x1_3 = x1.iloc[0:16, 2]
x1_4 = x1.iloc[0:16, 3]

y1=['GAMBoost','RLR','PMR','BGLM','PLR','GLM','PDA','LMT','FDA','SDWD','GLMBoost','GBM','MARS','SVM','GAMLOESS','NB']

plt.figure(figsize=(16,10))

plt.plot(y1,x1_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x1_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x1_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x1_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12) 

plt.xlabel('Classifier') 
plt.ylabel('Accuracy') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.4, 0.5, 0.5))

# %%
x2_1 = x2.iloc[0:16, 0]
x2_2 = x2.iloc[0:16, 1]
x2_3 = x2.iloc[0:16, 2]
x2_4 = x2.iloc[0:16, 3]

y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x2_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x2_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x2_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x2_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12) 

plt.xlabel('Classifier') 
plt.ylabel('Kappa Statistics') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.4, 0.5, 0.5))

# %%
x3_1 = x3.iloc[0:16, 0]
x3_2 = x3.iloc[0:16, 1]
x3_3 = x3.iloc[0:16, 2]
x3_4 = x3.iloc[0:16, 3]

y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x3_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x3_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x3_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x3_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12) 

plt.xlabel('Classifier') 
plt.ylabel('AUROC') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.5, 0.5, 0.5))

# %%
x4_1 = x4.iloc[0:16, 0]
x4_2 = x4.iloc[0:16, 1]
x4_3 = x4.iloc[0:16, 2]
x4_4 = x4.iloc[0:16, 3]

y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x4_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x4_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x4_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x4_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12)  

plt.xlabel('Classifier') 
plt.ylabel('Sensitivity') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.4, 0.5, 0.5))

# %%
x5_1 = x5.iloc[0:16, 0]
x5_2 = x5.iloc[0:16, 1]
x5_3 = x5.iloc[0:16, 2]
x5_4 = x5.iloc[0:16, 3]

y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x5_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x5_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x5_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x5_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12)  

plt.xlabel('Classifier') 
plt.ylabel('Specificity') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.5, 0.5, 0.5))

# %%
x6_1 = x6.iloc[0:16, 0]
x6_2 = x6.iloc[0:16, 1]
x6_3 = x6.iloc[0:16, 2]
x6_4 = x6.iloc[0:16, 3]

y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x6_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x6_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x6_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x6_4, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12)   

plt.xlabel('Classifier') 
plt.ylabel('Logloss') 

plt.legend(('Min','Median','Mean','Max'),loc='center right',bbox_to_anchor=(0.5, 0.35, 0.5, 0.5))

# %%
x7_1 = xall.iloc[0:16, 0]
x7_2 = xall.iloc[0:16, 1]
x7_3 = xall.iloc[0:16, 2]
x7_4 = xall.iloc[0:16, 3]
x7_5 = xall.iloc[0:16, 4]
x7_6 = xall.iloc[0:16, 5]


y1=['C1','C2','C3','C4','C5','C6','C7','C8','C9','C10','C11','C12','C13','C14','C15','C16']

plt.figure(figsize=(16,10))

plt.plot(y1,x7_1, color='green', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='green', markersize=12)   
plt.plot(y1,x7_2, color='red', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='red', markersize=12) 
plt.plot(y1,x7_3, color='blue', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x7_4, color='magenta', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='magenta', markersize=12)
plt.plot(y1,x7_5, color='orange', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='blue', markersize=12)   
plt.plot(y1,x7_6, color='black', linestyle='solid', linewidth = 3, marker='o', markerfacecolor='black', markersize=12)

plt.xlabel('Classifier') 
plt.ylabel('Values') 

plt.legend(('Accuracy','Kappa','Logloss','Sensitivity','AUROC','Specificity'))
